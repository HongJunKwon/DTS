# %%
plt.rcParams.update({'font.family':'Malgun Gothic'})

# %%
# 데이터 생성
data_with_recency = {
    '업체명': ["다우기술", "천재태블릿", "지니", "에이스디포", "오피스퀵", "라온웍스", "쥬크박스", "알파", "거영아이앤디", "조이스", 
              "블루스톤익스체인지", "애플나라샵", "한민유통", "지니 태블릿", "지니 태블릿(후불집행)", "이트너스", "더싸다닷컴", "빅픽처"],
    'Monetary': [3687810416, 2362932000, 1241881825, 316171800, 218748500, 215238580, 110472470, 41057164, 
                 36582310, 34393170, 90914460, 13236320, 10428760, 1455928000, 1081872000, 55596200, 53118000, 45763100],
    'Recency': ["2022-11-08 10:49:28", "2022-11-08 04:01:37", "2022-11-08 09:58:38", "2022-11-08 10:43:15", 
                "2022-11-07 17:35:11", "2022-11-07 13:09:34", "2022-11-08 09:58:38", "2022-11-08 01:57:09", 
                "2022-11-07 22:53:27", "2022-11-07 18:19:11", "2022-11-01 23:36:25", "2022-11-07 19:31:59", 
                "2022-11-07 16:28:56", "2022-01-28 23:53:15", "2022-05-31 21:53:22", "2022-11-01 18:07:14", 
                "2022-10-11 23:05:22", "2022-03-23 16:04:31"]
}

# 데이터프레임 생성
df_with_recency = pd.DataFrame(data_with_recency)

# Recency 컬럼을 datetime 타입으로 변환
df_with_recency['Recency'] = pd.to_datetime(df_with_recency['Recency'])

# 월별로 Monetary 합계 계산
monthly_monetary = df_with_recency.groupby(df_with_recency['Recency'].dt.month)['Monetary'].sum()

# 시각화
plt.figure(figsize=(10,6))
monthly_monetary.plot(kind='bar', color='skyblue')
plt.xlabel('월', fontsize=14)
plt.ylabel('매출', fontsize=14)
plt.title('월 별 매출 합계', fontsize=16)
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# 데이터 생성
data_2022 = {
    '업체명': ["다우기술", "천재태블릿", "지니", "에이스디포", "오피스퀵", "라온웍스", "쥬크박스", "알파", "거영아이앤디", "조이스", 
              "블루스톤익스체인지", "애플나라샵", "한민유통", "지니 태블릿", "지니 태블릿(후불집행)", "이트너스", "더싸다닷컴", "빅픽처"],
    'Monetary': [3687810416, 2362932000, 1241881825, 316171800, 218748500, 215238580, 110472470, 41057164, 
                 36582310, 34393170, 90914460, 13236320, 10428760, 1455928000, 1081872000, 55596200, 53118000, 45763100]
}

# 데이터프레임 생성
df_2022 = pd.DataFrame(data_2022)

# 2022년의 Monetary 합계 계산
total_monetary_2022 = df_2022['Monetary'].sum()

# 시각화
plt.figure(figsize=(10,6))
bars = plt.bar(['2022'], [total_monetary_2022], color='lightblue')

plt.xlabel('연도', fontsize=14)
plt.ylabel('매출)', fontsize=14)
plt.title('연도 별 매출 합계', fontsize=16)
plt.grid(axis='y')

# y축 레이블에 화폐 단위 '원'과 쉼표 추가
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# 막대 위에 금액 표시
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + total_monetary_2022*0.02, "{:,}원".format(int(yval)), 
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('profit.xlsx')

# %%
# 주문일자를 datetime 타입으로 변환
df['주문일자'] = pd.to_datetime(df['주문일자'])

# 월별 판매금액 합계 계산
monthly_sales = df.groupby(df['주문일자'].dt.to_period("M"))['판매금액'].sum()

# 시각화
plt.figure(figsize=(12,7))
monthly_sales.plot(kind='bar', color='lightseagreen')
plt.xlabel('월', fontsize=14)
plt.ylabel('매출', fontsize=14)
plt.title('월 별 순수익', fontsize=16)
plt.xticks(rotation=45)
plt.grid(axis='y')

# y축 레이블에 화폐 단위 '원'과 쉼표 추가
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

plt.tight_layout()
plt.show()
